# %%
import pytesseract
from PIL import Image

# %%
# If you don't have tesseract executable in your PATH, include the following:
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
# Example tesseract_cmd = r'C:\Program Files (x86)\Tesseract-OCR\tesseract'

# Simple image to string
print(pytesseract.image_to_string(Image.open("A:/Repositories/Capstone/data/raw/test.jpg")))

# In order to bypass the image conversions of pytesseract, just use relative or absolute image path
# NOTE: In this case you should provide tesseract supported images or tesseract will return error
print(pytesseract.image_to_string("A:/Repositories/Capstone/data/raw/test.jpg"))

# List of available languages
print(pytesseract.get_languages(config=''))



# Timeout/terminate the tesseract job after a period of time
try:
    print(pytesseract.image_to_string('test.jpg', timeout=2)) # Timeout after 2 seconds
    print(pytesseract.image_to_string('test.jpg', timeout=0.5)) # Timeout after half a second
except RuntimeError as timeout_error:
    # Tesseract processing is terminated
    pass

# Get bounding box estimates
print(pytesseract.image_to_boxes(Image.open('test.png')))

# Get verbose data including boxes, confidences, line and page numbers
print(pytesseract.image_to_data(Image.open('test.png')))

# Get information about orientation and script detection
print(pytesseract.image_to_osd(Image.open('test.png')))

# Get a searchable PDF
pdf = pytesseract.image_to_pdf_or_hocr('test.png', extension='pdf')
with open('test.pdf', 'w+b') as f:
    f.write(pdf) # pdf type is bytes by default

# Get HOCR output
hocr = pytesseract.image_to_pdf_or_hocr('test.png', extension='hocr')

# Get ALTO XML output
xml = pytesseract.image_to_alto_xml('test.png')

# getting multiple types of output with one call to save compute time
# currently supports mix and match of the following: txt, pdf, hocr, box, tsv
text, boxes = pytesseract.run_and_get_multiple_output('test.png', extensions=['txt', 'box'])
# Out:
# tics ss) Workplace Medical Center
# EDT TES! 100 Main Street
#
# Smithville, CA 90291
# (212) 555-4444
#
# \isit: www. paris-software.com/samples/workplaceprescriptions
#
# _THIS IS A PRESCRIPTION — PLEASE TAKE TO YOUR PHARMACY.
#
# Age: 67 Years — MRN: GSa-000555555
#
# L Pha pl plete, a
# Pat ient ‘Address: UNK Home Phone: — (555)777-7777,
# BLOOMINGDALE, IL 55555 Work Phone:
# | Prescription Details: Date Issued: 04/13/2015 |
# Rx: morphine 130 mg/24 hours oral capsule, extended release Start Date: 04/13/2015 |
# SIG: 130 mg = 1 cap Oral D: |
#
# Dispense/Supply:  **30** (thirty) cap - |
# sages |
#
# Refill:
# Rx: OXYcodone oral 10 mg tablet Start Date: 04/13/2015 |
# SIG: 10 mg = 1 fab Oral Q6H PRN for pain
# Dispense/Supply:  **120** (one hundred and twenty) tab |
# Refill: ages |
# : codeine sulfate oral 60 mg tablet Start Date: 04/13/2015
# SIG: 60 mg = 1 tab Oral Q4H PRN for pain
# Dispense/Supply:  **180** (one hundred and eighty) tab |
# Refil sages
#
# Rx: Norco oral 325-5 mg tablet Start Date: 04/13/2015 |
# SIG: 2 tab Oral Q4H PRN for pain |
# Dispense/Supply: **360** (three hundred and sixty) tab
# Refil sagee |
#
# x |
# DISPENSE AS WRITTEN SUBSTITUTION PERMITTED |
# |
#
# Prescribed by: Doc Test DEA#: HLLIIL NPI #: 2222222
#
# Entered by: RNI RN
#
# workplaceprescriptions
#
# ion Security Features:
#
# 1. The border around the prescription is micro-printed with the Pationts Name visible under $x oF greater magnification, Patient's name illegible if photocopied or
# scanned.
#
# 2. The text "RX ORIGINAL RX" visible inthe botiom center ofthe document with light gray patterned background and will be missing when photocopicd or scanned
#
# 3. The text "VOID" appears when scanned or photocopied.
#
# 4. Quantities and refills enclosed in asterisks.
#
#
# workplaceprescriptions
#
# workpl: Workplace Medical Center
# EDT TSE 100 Main Street
#
# | Smithville, CA 90291
#
# \isit: www. paris-software.com/samples/workplaceprescriptions,
#
# (212) 555-4444
#
# THIS IS A PRESCRIPTION -- PLEASE TAKE TO YOUR PHARMACY. |
#
# Age: 67 Years — MRN: GSa-000555555
#
# Patient Address: UNK Home Phone: (555)777-7777
# BLOOMINGDALE, IL $5555 Work Phone:
# Prescription Details: Date Issued: 04/13/2015 |
# Rx: morphine 130 mg/24 hours oral capsule, extended release Start Date; 04/13/2015
# SIG: 130 mg = I cap Oral D: |
# Dispense/Supply: _ **30** (thirty) cap
# Refill: sige |
# Rx: OXYcodone oral 10 mg tablet Start Date: 04/13/2013 |
# si 10 mg=1 tab Oral Q6H PRN for pain |
#
# Dispense/Supply: _**120** (one hundred and twenty) tab
#
# Refill: sages |
# : codeine sulfate oral 60 mg tablet Start Date: 04/13/2015 |
# SIG: 60 mg = 1 tab Oral Q4H PRN for pain |
# Dispense/Supply: __**180** (one hundred and eighty) tab |
# Refil gee |
# Norco oral 325-5 mg tablet Start Date: 04/13/2015 |
#
# SIG: 2 tab Oral Q4H PRN for pain
# Dispense/Supply:  **360** (three hundred and sixty) tab |
# Refi sages |
#
# x.
#
# DISPENSE AS WRITTEN SUBSTITUTION PERMITTED |
# Prescribed by: Doc Test DEA#: HLL NPI #: 2222222 |
#
# Entered by: RNI RN
#
# jon Security Features:
#
# 1. The border around the prescription is micro-printed with the Patient's Name visible under Sx or greater magnification, Patient's name illegible i photocopied oF
# scanned.
#
# 2. The text "RX ORIGINAL RX" visible inthe bottom center ofthe document with light gray patterned background and willbe missing when photocopicd or scanned
#
# 3. The text "VOID" appears when scanned or photocopied
#
# 4. Quantities and refills enclosed in asterisks.
#
#
# ['eng', 'osd']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 16
#      13 print(pytesseract.get_languages(config=''))
#      15 # French text image to string
# ---> 16 print(pytesseract.image_to_string(Image.open('test-european.jpg'), lang='fra'))
#      18 # Batch processing with a single file containing the list of multiple image file paths
#      19 print(pytesseract.image_to_string('images.txt'))
#
# File a:\Repositories\Capstone\.venv\Lib\site-packages\PIL\Image.py:3469, in open(fp, mode, formats)
#    3466     filename = os.path.realpath(os.fspath(fp))
#    3468 if filename:
# -> 3469     fp = builtins.open(filename, "rb")
#    3470     exclusive_fp = True
#    3471 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'A:\\Repositories\\Capstone\\notebooks\\test-european.jpg'
